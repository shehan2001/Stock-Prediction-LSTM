# %% [markdown]
# # ALgorithmic trading - stock market price prediction
#
# # Introduction
#
# The paper below discusses stock market prediction using RNN which is a popular time series problem model. This paper tries to identify what the best approach is by getting the highest accuracy to the real world figures. simpleRNN, LSTM, and GRU will be discussed. How it’s applied and the test done to finalize on what the best option is.
#
# # Part A - Literature review
#
# AI has been continuously used in multiple industries, like medical, financial , etc. This includes Algorithmic trading as well.
#
# Algorithmic trading is known as automated trading where it issues orders automatically depending on the data the algorithm has been trained on like for example price, time and volume. A major example of Algorithmic trading is stock market price prediction
#
#
# **stock market price prediction.**
#
# Traditionally there are multiple ways of analyzing / predicting the stock market. In this report the author chose to do so using a time based /series system. A time based system aims to analyze data through patterns, trends and periods or cycles in the data(Sutradhar et al, 2021).
#
# As per (Jahan, 2018) published, a study was done where they concluded that the non-linear model performed better than the linear model that was chosen.
#
#
# **Non-linear Model (Recurrent neural network)** -
#
#  In the Recurrent neural network, it allows signals to travel in both directions by introducing loops in the network. There is a feedback (loops), and feedback networks are powerful, dynamic and can get extremely complicated. Their ’state’ is changing continuously until they reach an equilibrium point. In stock price prediction we need a dynamic feedback network where we can follow the unpredictable trend of the stock price dynamically. That’s why the author has selected  recurrent neural networks for this work.(Jahan, 2018).
#
# There are 3 main layers of an RNN by default. Simple RNN, LSTM and GRU(Tensorflow, n.d.). These 3 layers will be used with the same environment, i.e: datasets, epochs levels, batch size, etc. and tested amongst each other to see which technique of using which layer independently would provide the best and most accurate prediction.
#
# LSTM and GRU will be discussed below as they are an  addition to the simple RNN, fixing issues that the simpleRNN has. These issues will be spoken into more details as the report goes on.
#
# Stock market prediction is a time series analysis, therefore RNN and LSTM are well suited to be used for this scenario.
#
# Many studies have been conducted to investigate the use of RNNs and LSTMs for stock market prediction.In a study by (Shah et al., 2018), it proposes that RNN LSTM works better than DNN in terms of performance and predictability. The arthur also mentions how LSTM could be promising when it comes to predicting long term predictions on volatile stock data.
# Other Studies like  (Bathla, 2020) and (Karmiani1 et al., 2019), shows that LSTM performs better than SVR(Support vector regression),  and LSTM performs better and being more reliable  than Backpropagation and SVM; respectively.
#
# Another well known method is using RNN with GRU which like the above mentioned LSTM is equally capable in Time series style problems(sequential data).
# As mentioned in (Chung et al., 2014), the author proposes that the GRU architecture showed similar results to LSTM.
#
#
#
# In conclusion, the studies as mentioned above shows that a combination of RNN and LSTM produces or RNN and GRU  fruitful results with high accuracy, GRU and LSTM has its own pros and cons which might determine the final choice which would be discussed below as the report goes on.  However, note that the stock markets  could also be altered by global scenarios/ issues like wars, political instability which cannot be controlled. Time based system would work well if the conditions and uncontrollable variables are the same as prior years.
#
#
# # Part B – Compare and evaluate AI techniques.
#
# **Brief examples of how each technique can be applied to your problem**-
#
# The overall test for the 3 mentioned models are the same with very slight changes that were made to increase the accuracy. The reasoning as to why the env was the same throughout the test was to keep the test fair among the 3.
#
#
# **simpleRNN** - The dataset used for this was the same as used for other models. Epochs are the same at 100 with batch size at 32. In this case the Internal Units was reduced to 25 as increasing would flatten the line,underfitting the result, showing no relationship. 25 was the sweet spot. Dropouts were added to prevent overfitting.  This settings amongst others were then set to train with the dataset. The result was this
# ![image.png](attachment:image.png)
# As you can see, it isn’t very accurate using the simpleRNN. This happens because of an issue RNN has that LSTM and GRU fixes which is Vanishing gradient.  As the gradient carries information, which loses some of its information as time and training goes on. Which therefore leaves an in-accurate result or prediction.
#
#
# **GRU** - GRU was carried out with the same settings and variables but the internal unit was adjusted to 100  as this was the sweet spot for this training session. The result below shows that GRU performed far better than simpleRNN did.
# ![image-2.png](attachment:image-2.png)
# But as you can see, the prediction doesn’t get the exact price value as the real price for the year but if you look closely, the shape between the two looks similar, the bring in more context; as the predicted value goes up, the actual value is also in an upwards motion and it’s the same case downwards at certain points. Overall this is a safe result as the investor could still know if and when the price will increase or decrease even though the exact value of the increase or decrease isn’t right.
#
#
# **LSTM** -The variables and environment for this test is exactly the same as GRU other than the layers being swapped with LSTM layers.
# ![image-3.png](attachment:image-3.png)
# As this result shows, in this case, the pricing of the stocks are closer to the actual value(at times) even though the direction of growth or descent isn’t accurate as compared to GRU.
#
# **Strengths and weaknesses, advantages, and disadvantages of each technique** -
#
#
#
# **SimpleRNN** -
#
# Strength 01- Being able to handle sequential data
# Advantage 01 - This helps in doing time series / base analysis which could benefit stock market predictions.
# Strength 02-  Can do non-linear relationships between inputs and outputs
# Advantage 02 - Non-linear relationships can benefit stock market predictions as the financial market is volatile / not linear in its data
# Strength 03-  Can handle multivariate data.
# Advantage 03 -  multivariate data can result in more accurate predictions as it has gone through many cycles of training through the multiple layers.This also means that  more than one input can be inserted which could help train the model better as there are more variables to train on.
#
#
#
# Weakness 01-  Vanishing and Exploding Gradients
# Disadvantage 01 -Disadvantage - Inaccurate final prediction
# Weakness 02- Inability to handle high-dimensional data
# Disadvantage 02- Disadvantage - Inaccurate final prediction
# Weakness 03-  limited performance compared to LSTM and GRU.
# Disadvantage 03- Disadvantage - Inaccurate final prediction
#
#
#
#
#
# **LSTM** -
#
#
# Strength 01- Handling long-term dependencies
# Advantage 01 - Helps it remember previous values from previous nodes, makes the trained model smarter and provide more accurate results
# Strength 02-  Handling large-scale datasets
# Advantage 02 Larger datasets that models are trained on can help build its accuracy
# Strength 03-  Handling non-linear relationships.
# Advantage 03 -   can help in doing time series related projects like stock market predictions.
#
# Weakness 01-   Computationally intensive
# Disadvantage 01 - slow down your computer or device
# Weakness 02- Overfitting
# Disadvantage 02- inaccurate predictions to new data that is not the trained data
# Weakness 03- Difficulty in parallelizing
# Disadvantage 03-  training takes longer.
#
#
#
#
#
#
# **GRU** -
#
# Strength 01- computationally efficient
# Advantage 01 - uses less resource and taxes the pc or device less
# Strength 02-  Handling long-term dependencies
# Advantage 02 - Helps it remember previous values from previous nodes, makes the trained model smarter and provide more accurate results
# Strength 03-  Handling large-scale datasets
# Advantage 03 -  Larger datasets that models are trained on can help build its accuracy.
#
#
# Weakness 01-   Handling non-linear relationships
# Disadvantage 01 - GRUs may not be as effective as LSTMs in capturing non-linear relationships between inputs and outputs, which might affect the accuracy
# Weakness 02- Overfitting
# Disadvantage 02-in-accurate prediction due to poor generalization.
#
#
#
# **Input data required and expected output from each technique** -
#
#  Input data for all 3 were .csv files with Date, Open, High, Low, Close, Volume as columns.  Output is a prediction chart with the price in its y-axis and time in it’s x-axis
#
# LSTM was picked and compared with the rest.
#
# # Part C – Implementation.
#
# **A** -
#  Input required - initial training data to train was a .csv file consisting of over 1200 rows(Date, Open, High, Low, Close, Volume as columns). The data collected / present here are data of stock prices of google from previous years. The test data are data of the stock prices from the years after from when the test data ends. These are too in the same format as the training data. Data preprocessing/ adjustments  were done to clean the data that would be fed to the training model.  The data in this case is time series data.
#
# **B** -
#
# **LSTM** -
#  ![image-4.png](attachment:image-4.png)
# **GRU** -
# ![image-5.png](attachment:image-5.png)
# **SimpleRNN** -
# ![image-6.png](attachment:image-6.png)
# **C** -
# The code base for LSTM will shown below. Code base for GRU and simpleRNN can be found within the same folder.
#
# # Part D – Evaluation and Testing
#
# The test was done using r2_score method, which is a great way to test time based or continuous data related problems
#
# simpleRNN got a test result of -2.38, which shows that this prediction isn’t trustable and not safe.
#
# GRU got a prediction of -1.12, which indicates that this method / technique is not the most accurate.
#
# LSTM got a prediction of 0.475 which isn’t good in itself but compared to the rest of the result is the best prediction option. Furthermore, as discussed above, the comparisons of the predicted results were shown with the actual result for further clarification on how accurate the predictions were.
#
# Part E – Evaluate results
#
# The author has discussed in this paper the performance of simpleRNN, LSTM and GRU. As seen from the results, with the current amount of data available, the author saw that LSTM performed better with the same conditions. Therefore LSTM would be the preferred way to go to predict stock prices with a larger dataset to train.
#
#
#
#
#
# # References
#
# Bathla, G. (2020) Stock price prediction using LSTM and SVR - IEEE xplore. Available at: https://ieeexplore.ieee.org/abstract/document/9315800/ (Accessed: January 17, 2023).
#
# Chung, J. et al. (2014) Empirical evaluation of gated recurrent neural networks on sequence modeling, arXiv.org. Available at: https://arxiv.org/abs/1412.3555 (Accessed: January 17, 2023).
#
# Jahan, I. (2018) Stock price prediction using recurrent neural networks a paper, STOCK PRICE PREDICTION USING RECURRENT NEURAL NETWORKS. Available at: https://library.ndsu.edu/ir/bitstream/handle/10365/28797/Stock%20Price%20Prediction%20Using%20Recurrent%20Neural%20Networks.pdf (Accessed: January 17, 2023).
#
# Karmiani1, D. et al. (2019) Comparison of predictive algorithms: Backpropagation, SVM ... - IEEE xplore. Available at: https://ieeexplore.ieee.org/abstract/document/8701258/ (Accessed: January 17, 2023).
#
# Shah, D., Campbell, W. and Zulkernine, F.H. (2018) A comparative study of LSTM and DNN for stock market forecasting, A Comparative Study of LSTM and DNN for Stock Market Forecasting. Available at: https://ieeexplore.ieee.org/abstract/document/8622462/ (Accessed: January 17, 2023).
#
#
# Sutradhar, K. et al. (no date) IEEE Xplore, Stock Market Prediction using Recurrent Neural  Network’s LSTM Architecture. Available at: https://ieeexplore.ieee.org/Xplore/dynhome.jsp (Accessed: January 17, 2023).
#
# Dataset link - https://drive.google.com/drive/folders/1iH8pbxLqHCJdGcNKqFB_DeweLDPPhZbJ?usp=sharing

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime

# %%
# Dataset for training
dataset = pd.read_csv('Google_Stock_Price_Train.csv',index_col="Date",parse_dates=True)

# %%
# used to check for missing values
dataset.isna().any()
# Out:
# Open      False
# High      False
# Low       False
# Close     False
# Volume    False
# dtype: bool

# %%
# selects column of "Close", replaces any value with comma and replaces it with " ". It also converts the string into a float
dataset["Close"] = dataset["Close"].str.replace(',', '').astype(float)

# %%
# selects column of "Volume", replaces any value with comma and replaces it with " ". It also converts the string into a float
dataset["Volume"] = dataset["Volume"].str.replace(',', '').astype(float)

# %%
# 7 day rolling mean
dataset.rolling(7).mean().head(20)
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2012-01-03         NaN         NaN         NaN         NaN           NaN
# 2012-01-04         NaN         NaN         NaN         NaN           NaN
# 2012-01-05         NaN         NaN         NaN         NaN           NaN
# 2012-01-06         NaN         NaN         NaN         NaN           NaN
# 2012-01-09         NaN         NaN         NaN         NaN           NaN
# 2012-01-10         NaN         NaN         NaN         NaN           NaN
# 2012-01-11  323.002857  325.392857  318.682857  643.132857  7.208100e+06
# 2012-01-12  321.457143  322.882857  316.841429  638.037143  6.691514e+06
# 2012-01-13  318.698571  319.801429  314.025714  631.870000  6.531857e+06
# 2012-01-17  316.552857  317.524286  311.851429  627.534286  6.137929e+06
# 2012-01-18  314.238571  315.674286  309.882857  625.097143  6.157657e+06
# 2012-01-19  313.847143  315.247143  310.610000  627.534286  6.296086e+06
# ...

# %%
# Used to calculate a rolling mean of the "Close" column in the DataFrame "dataset" and adds it as a new column named "Close: 30 Day Mean"
dataset['Close: 30 Day Mean'] = dataset['Close'].rolling(window=30).mean()

# %%
training_set=dataset['Open']
training_set=pd.DataFrame(training_set)

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
# Creating a data structure with 60 timesteps and 1 output
X_train = []
y_train = []
for i in range(60, 1258):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# Reshaping
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# Part 2 - Building the RNN

# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dropout

# %%
# Initialising the RNN
regressor = Sequential()

# %%
# Adding the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 100, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 100, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 100, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 100))
regressor.add(Dropout(0.2))

# Adding the output layer and some Dropout regularisation
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))

# %%
# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 17s 193ms/step - loss: 0.0285
# Epoch 2/100
# 38/38 [==============================] - 7s 187ms/step - loss: 0.0058
# Epoch 3/100
# 38/38 [==============================] - 7s 185ms/step - loss: 0.0054
# Epoch 4/100
# 38/38 [==============================] - 8s 201ms/step - loss: 0.0049
# Epoch 5/100
# 38/38 [==============================] - 8s 222ms/step - loss: 0.0048
# Epoch 6/100
# 38/38 [==============================] - 8s 205ms/step - loss: 0.0050
# Epoch 7/100
# 38/38 [==============================] - 8s 223ms/step - loss: 0.0052
# Epoch 8/100
# 38/38 [==============================] - 9s 225ms/step - loss: 0.0041
# Epoch 9/100
# 38/38 [==============================] - 8s 210ms/step - loss: 0.0043
# Epoch 10/100
# 38/38 [==============================] - 8s 204ms/step - loss: 0.0046
# Epoch 11/100
# 38/38 [==============================] - 8s 212ms/step - loss: 0.0049
# Epoch 12/100
# ...

# %%
# Part 3 - Making the predictions and visualising the results

# Getting the real stock price of 2017
dataset_test = pd.read_csv('Google_Stock_Price_Test.csv',index_col="Date",parse_dates=True)

# %%
real_stock_price = dataset_test.iloc[:, 1:2].values

# %%
dataset_test.head()
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2017-01-03  778.81  789.63  775.80  786.14  1,657,300
# 2017-01-04  788.36  791.34  783.16  786.90  1,073,000
# 2017-01-05  786.08  794.48  785.02  794.02  1,335,200
# 2017-01-06  795.26  807.90  792.20  806.15  1,640,200
# 2017-01-09  806.40  809.97  802.83  806.65  1,272,400

# %%
dataset_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20 entries, 2017-01-03 to 2017-01-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    20 non-null     float64
#  1   High    20 non-null     float64
#  2   Low     20 non-null     float64
#  3   Close   20 non-null     float64
#  4   Volume  20 non-null     object
# dtypes: float64(4), object(1)
# memory usage: 960.0+ bytes

# %%
dataset_test["Volume"] = dataset_test["Volume"].str.replace(',', '').astype(float)

# %%
test_set=dataset_test['Open']
test_set=pd.DataFrame(test_set)

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20 entries, 2017-01-03 to 2017-01-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    20 non-null     float64
# dtypes: float64(1)
# memory usage: 320.0 bytes

# %%
# Getting the predicted stock price of 2017
dataset_total = pd.concat((dataset['Open'], dataset_test['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 80):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 3s 3s/step

# %%
predicted_stock_price=pd.DataFrame(predicted_stock_price)
predicted_stock_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       20 non-null     float32
# dtypes: float32(1)
# memory usage: 208.0 bytes

# %%
# Visualising the results
plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import r2_score


accuracy = r2_score(real_stock_price, predicted_stock_price)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.4750878468537503
